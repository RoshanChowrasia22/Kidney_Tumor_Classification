# %%
from cnnClassifier import logger

logger.info("HOLA")
# Out:
# [2025-11-10 21:47:42,942: INFO: 2328334002: HOLA]

# %%
from box import ConfigBox
ds=ConfigBox({"r":"o","s":"h","a":"n"})

# %%
ds.r
# Out:
# 'o'

# %%
ds.items()
# Out:
# dict_items([('r', 'o'), ('s', 'h'), ('a', 'n')])

# %%
from ensure import ensure_annotations
@ensure_annotations
def get_prod(x:float,y:float)->float:
    return x*y
get_prod(2.0,3.0)
# Out:
# 6.0

# %%
import gdown
url="https://drive.google.com/file/d/1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3/view?usp=sharing"
file_id = url.split("/")[-2]
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "kidney-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3&confirm=t&uuid=ff55b4b8-71ff-4ea4-89f4-5027ab1d9f0f
# To: c:\Users\Roshan\Desktop\Kidney_Classification\Kidney_Tumor_Classification\kidney-CT-Scan-data.zip
# 100%|██████████| 57.7M/57.7M [00:37<00:00, 1.56MB/s]
# 'kidney-CT-Scan-data.zip'
